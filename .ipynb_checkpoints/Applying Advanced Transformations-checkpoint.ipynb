# %% [markdown]
# ## Preprocessing

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %%
df_powers = pd.read_csv("C:\\Users\\Alexander\\Downloads\\superhero_powers - superhero_powers.csv")
df_powers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
df_hero = pd.read_csv("C:\\Users\\Alexander\\Downloads\\superhero_info - superhero_info.csv")
df_hero.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df_powers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
df_hero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %%
df_hero['Hero|Publisher'].str.split(' ',expand=True)
# split the columns
# Out:
#                        0            1       2       3
# 0          A-Bomb|Marvel       Comics    None    None
# 1                    Abe  Sapien|Dark   Horse  Comics
# 2                   Abin       Sur|DC  Comics    None
# 3     Abomination|Marvel       Comics    None    None
# 4              Absorbing   Man|Marvel  Comics    None
# ..                   ...          ...     ...     ...
# 458  Yellowjacket|Marvel       Comics    None    None
# 459         Yellowjacket    II|Marvel  Comics    None
# 460          Yoda|George        Lucas    None    None
# 461           Zatanna|DC       Comics    None    None
# 462              Zoom|DC       Comics    None    None
#
# [463 rows x 4 columns]

# %%
## save the 2 new columns into the dataframe
df_hero[['Hero','Publisher']] = df_hero['Hero|Publisher'].str.split('|',expand=True)
df_hero.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
## drop the original column 
df_hero = df_hero.drop(columns=['Hero|Publisher'])
df_hero.head(3)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
# 2   Male        Ungaran      good    No Hair      blue        red
#
#                                    Measurements        Hero          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}    Abin Sur          DC Comics

# %%
## use .str.replace to replace all single quotes
df_hero['Measurements'] = df_hero['Measurements'].str.replace("'",'"')
## Apply the json.loads to the full column
df_hero['Measurements'] = df_hero['Measurements'].apply(json.loads)
df_hero['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
## check a single value after transformation
test_coord = df_hero.loc[0, 'Measurements']
print(type(test_coord))
test_coord
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
# f we use the pandas pd.Series function on our column of dictionaries, 
#it will automatically convert each key to a new column
h_w = df_hero['Measurements'].apply(pd.Series)
h_w
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
#Now, we concatenate these 2 new columns to our  original dataframe 
df_hero = pd.concat((df_hero, h_w), axis = 1)
df_hero.head(3)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
# 2   Male        Ungaran      good    No Hair      blue        red
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}    Abin Sur
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg
# 2          DC Comics  185.0 cm   90.0 kg

# %%
#AAAAANNNND drop the original column.
df_hero = df_hero.drop(columns=['Measurements'])
df_hero.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg

# %%
## examining a single value from the coordinates col
coord = df_powers.loc[0,"Powers"]
print(type(coord))
coord
# Out:
# <class 'str'>
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
coord = coord.replace("'","''")
coord
# Out:
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
# Convert a column that contains lists (that were converted to strings), back to lists.
## showing the lists are really strings
df_powers.loc[2,'Powers']
# Out:
# 'Agility,Accelerated Healing,Cold Resistance,Durability,Underwater breathing,Marksmanship,Weapons Master,Longevity,Intelligence,Super Strength,Telepathy,Stamina,Immortality,Reflexes,Enhanced Sight,Sub-Mariner'

# %%
# Create a new column where the single quotes are replaced by double quotes
df_powers['Powers'] = df_powers['Powers'].str.replace("'",'"')

# %%
# Apply json.loads to entire column
df_powers['Powers'] = df_powers['Powers'].apply(json.loads)
# check results
df_powers['Powers'].head(3)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In [297], line 2
#       1 # Apply json.loads to entire column
# ----> 2 df_powers['Powers'] = df_powers['Powers'].apply(json.loads)
#       3 # check results
#       4 df_powers['Powers'].head(3)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
# ...
